# %% [markdown]
# # Preparing dataset
#
# We will use the BX-Book-Ratings dataset for this week's notebooks. This dataset is large but also sparse: it contains many books with very few ratings, and user who have made very few ratings.
#
# We can't make accurate predictions based on ratings for these books and users (cold start problem), so we filter the dataset here.
#
# In a complete recommender system, you will need to think of alternative ways you could give recommendations to new or inactive users, and to make sure new items in the catalogue can be recommended to users.

# %%
import pandas as pd
df_books_ratings = pd.read_csv('../jaccard-distance/data/BX-Book-Ratings.csv', sep=';', encoding='latin-1')

# %% [markdown]
# Create a subset of the data and save a copy so that you can use it later.
#
# Please filter out:
#
# * users that have less than 20 ratings
# * books that have less than 20 ratings

# %%
# df = ...

# %%
df.to_csv('data/BX-Book-Ratings-Subset.csv', index=False, sep=';')
