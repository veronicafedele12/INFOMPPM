# %% [markdown]
# # K-means clustering (another dataset)
#
# As you might have noticed, there is another dataset in the data directory called `ML-ratings.csv`. This data comes from MovieLens and is a small subset of the data used in our book.
#
# Can you cluster this data using the same methods as seen before (notebook 3)?  Is the clustering better than our books dataset or not?

# %%
import pandas as pd
df_ml_ratings = pd.read_csv('data/ML-ratings.csv', sep=',')
df_ml_ratings

# %%
# code goes here
